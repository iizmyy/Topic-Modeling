# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import time

# Add chromedriver to path in LINUX
# sudo ln -s /home/izmy/Blog/chromedriver /usr/bin/
driver = webdriver.Chrome(executable_path='chromedriver')

#url = "https://www.tripadvisor.co.id/Attraction_Review-g297720-d1599792-Reviews-Fort_Rotterdam-Makassar_South_Sulawesi_Sulawesi.html"
#url = "https://www.tripadvisor.co.id/Attraction_Review-g297720-d1599792-Reviews-or60-Fort_Rotterdam-Makassar_South_Sulawesi_Sulawesi.html"
#url = "https://www.tripadvisor.co.id/Attraction_Review-g297720-d13195841-Reviews-Mall_Phinisi_Point-Makassar_South_Sulawesi_Sulawesi.html"
#url = "https://www.tripadvisor.co.id/Attraction_Review-g297720-d13195841-Reviews-or20-Mall_Phinisi_Point-Makassar_South_Sulawesi_Sulawesi.html"
urls = ["https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or10-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or20-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or30-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or40-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or50-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or60-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or70-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or80-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or90-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or100-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or110-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or120-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or130-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or140-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or150-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or160-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or170-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or180-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or190-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or200-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or210-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or220-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or230-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or240-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or250-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or260-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or270-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or280-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or290-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or300-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or310-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or320-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or330-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or340-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or350-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or360-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or370-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or380-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or390-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or400-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or410-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or420-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or430-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or440-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or450-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or460-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or470-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or480-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or490-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or500-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or510-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or520-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or530-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or540-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or550-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or560-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or570-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or580-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or590-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or600-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or610-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or620-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or630-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or640-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or650-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or660-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or670-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or680-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or690-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or700-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or710-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or720-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or730-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or740-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or750-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or760-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or770-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or780-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or790-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or800-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or810-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or820-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or830-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or840-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or850-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or860-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or870-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or880-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or890-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or900-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or910-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or920-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or930-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or940-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or950-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or960-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or970-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or980-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or990-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html",
        "https://www.tripadvisor.co.id/Attraction_Review-g297720-d777660-Reviews-or1000-Losari_Beach-Makassar_South_Sulawesi_Sulawesi.html"
        ]
for url in urls :
    driver.get(url)
    time.sleep(10)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    time.sleep(3)
    #driver.quit()
    reviews = soup.select("div.pIRBV._T.KRIav")

    r = [review.find("span").text for review in reviews]

    # menyimpan ke dataframe
    df = pd.DataFrame(r,columns=["review"])
    #print(df)

    # Review tambahkan ke file
    #df.to_csv('reviewphinisi.csv', mode='a', header=False)
    df.to_csv('reviewLosari.csv', mode='a', header=False)
driver.quit()

# %%
pip install webdriver-manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/home/izmy/.wdm/drivers/chromedriver/linux64/98.0.4758.102/chromedriver] found in cache

# %%
# Out:
# https://www.tripadvisor.co.id/Attraction_Review-g297720-d2716851-Reviews-or120-Trans_Studio_Makassar-Makassar_South_Sulawesi_Sulawesi.html
# https://www.tripadvisor.co.id/Attraction_Review-g297720-d2716851-Reviews-or130-Trans_Studio_Makassar-Makassar_South_Sulawesi_Sulawesi.html
# https://www.tripadvisor.co.id/Attraction_Review-g297720-d2716851-Reviews-or140-Trans_Studio_Makassar-Makassar_South_Sulawesi_Sulawesi.html
